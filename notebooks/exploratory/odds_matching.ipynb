# %%
import pandas as pd
import sqlite3
from thefuzz import fuzz
from thefuzz import process


# Load the data
conn = sqlite3.connect('../../data/raw/master.db')

odds_data = pd.read_csv('../../data/processed/odds.csv')

print(odds_data.head())
# Out:
#   Div        Date            HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  D1  24/08/2018       Bayern Munich     Hoffenheim     3     1   H     1
# 1  D1  25/08/2018  Fortuna Dusseldorf       Augsburg     1     2   A     1
# 2  D1  25/08/2018            Freiburg  Ein Frankfurt     0     2   A     0
# 3  D1  25/08/2018              Hertha       Nurnberg     1     0   H     1
# 4  D1  25/08/2018          M'gladbach     Leverkusen     2     0   H     0
#
#    HTAG HTR  ...  1XBCH  1XBCD  1XBCA  BFECH  BFECD  BFECA  BFEC>2.5  \
# 0     0   H  ...    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 1     0   H  ...    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 2     1   A  ...    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 3     0   H  ...    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 4     0   D  ...    NaN    NaN    NaN    NaN    NaN    NaN       NaN
#
#    BFEC<2.5  BFECAHH  BFECAHA
# 0       NaN      NaN      NaN
# 1       NaN      NaN      NaN
# 2       NaN      NaN      NaN
# 3       NaN      NaN      NaN
# 4       NaN      NaN      NaN
#
# [5 rows x 153 columns]
# /var/folders/k5/sqpgl_zj3yg5kn6h04ymp5z40000gn/T/ipykernel_47108/637560664.py:10: DtypeWarning: Columns (130) have mixed types. Specify dtype option on import or set low_memory=False.
#   odds_data = pd.read_csv('../../data/processed/odds.csv')

# %%
teams_query = """
SELECT distinct home_team FROM Match
"""
teams_df = pd.read_sql_query(teams_query, conn)

print(teams_df.head())
# Out:
#         home_team
# 0         Arsenal
# 1         Watford
# 2  Crystal Palace
# 3       West Brom
# 4         Chelsea

# %%
# Get unique teams from odds data
odds_home_teams = set(odds_data['HomeTeam'].unique())
odds_away_teams = set(odds_data['AwayTeam'].unique())
odds_teams = list(odds_home_teams.union(odds_away_teams))


# Create a mapping dictionary starting with exact matches
team_name_mapping = {}

# For each team that only exists in match data, find closest match in odds data
for odds_team in odds_teams:
    # Find closest matching team from odds data using process.extractOne
    # This returns tuple of (match, score, index)
    best_match = process.extractOne(odds_team, teams_df['home_team'], scorer=fuzz.ratio)
    
    if best_match[1] >= 40:  # Only include matches with 80% or higher similarity
        team_name_mapping[odds_team] = best_match[0]
        print(f"Fuzzy match: {odds_team} -> {best_match[0]} (Score: {best_match[1]})")

print("\nTotal mappings found:", len(team_name_mapping))
print("\nSample of mappings (including exact matches):")
for k, v in list(team_name_mapping.items())[:5]:
    print(f"{k} -> {v}")
# Out:
# Fuzzy match: Cadiz -> Cádiz (Score: 80)
# Fuzzy match: Fortuna Dusseldorf -> Düsseldorf (Score: 64)
# Fuzzy match: Clermont -> Clermont Foot (Score: 76)
# Fuzzy match: West Brom -> West Brom (Score: 100)
# Fuzzy match: Brighton -> Brighton (Score: 100)
# Fuzzy match: Venezia -> Venezia (Score: 100)
# Fuzzy match: Rennes -> Rennes (Score: 100)
# Fuzzy match: Milan -> Milan (Score: 100)
# Fuzzy match: Aston Villa -> Aston Villa (Score: 100)
# Fuzzy match: Arsenal -> Arsenal (Score: 100)
# Fuzzy match: Nimes -> Nîmes (Score: 80)
# Fuzzy match: Inter -> Inter (Score: 100)
# Fuzzy match: Troyes -> Troyes (Score: 100)
# Fuzzy match: Tottenham -> Tottenham (Score: 100)
# Fuzzy match: Dortmund -> Dortmund (Score: 100)
# Fuzzy match: Lens -> Lens (Score: 100)
# Fuzzy match: Heidenheim -> Heidenheim (Score: 100)
# Fuzzy match: Benevento -> Benevento (Score: 100)
# Fuzzy match: Stoke -> Stoke City (Score: 67)
# Fuzzy match: Ein Frankfurt -> Eint Frankfurt (Score: 96)
# Fuzzy match: Atalanta -> Atalanta (Score: 100)
# Fuzzy match: Reims -> Reims (Score: 100)
# Fuzzy match: FC Koln -> Köln (Score: 55)
# Fuzzy match: Leganes -> Leganés (Score: 86)
# Fuzzy match: Bordeaux -> Bordeaux (Score: 100)
# Fuzzy match: Napoli -> Napoli (Score: 100)
# Fuzzy match: Mainz -> Mainz 05 (Score: 77)
# Fuzzy match: Leicester -> Leicester City (Score: 78)
# Fuzzy match: Vallecano -> Rayo Vallecano (Score: 78)
# Fuzzy match: Eibar -> Eibar (Score: 100)
# Fuzzy match: Spal -> SPAL (Score: 100)
# Fuzzy match: St Pauli -> St. Pauli (Score: 94)
# Fuzzy match: Man City -> Swansea City (Score: 70)
# Fuzzy match: Swansea -> Swansea City (Score: 74)
# Fuzzy match: Bochum -> Bochum (Score: 100)
# Fuzzy match: Espanol -> Espanyol (Score: 93)
# Fuzzy match: Stuttgart -> Stuttgart (Score: 100)
# Fuzzy match: Lazio -> Lazio (Score: 100)
# Fuzzy match: La Coruna -> La Coruña (Score: 89)
# Fuzzy match: Brentford -> Brentford (Score: 100)
# Fuzzy match: Granada -> Granada (Score: 100)
# Fuzzy match: Sociedad -> Real Sociedad (Score: 76)
# Fuzzy match: Greuther Furth -> Greuther Fürth (Score: 93)
# Fuzzy match: Bournemouth -> Bournemouth (Score: 100)
# Fuzzy match: Crotone -> Crotone (Score: 100)
# Fuzzy match: Paris SG -> Paris S-G (Score: 94)
# Fuzzy match: Brescia -> Brescia (Score: 100)
# Fuzzy match: Lille -> Lille (Score: 100)
# Fuzzy match: Leeds -> Lens (Score: 67)
# Fuzzy match: Malaga -> Málaga (Score: 83)
# Fuzzy match: Ipswich -> Ipswich Town (Score: 74)
# Fuzzy match: M'gladbach -> Gladbach (Score: 89)
# Fuzzy match: Hannover -> Hannover 96 (Score: 84)
# Fuzzy match: Southampton -> Southampton (Score: 100)
# Fuzzy match: Norwich -> Norwich City (Score: 74)
# Fuzzy match: Villarreal -> Villarreal (Score: 100)
# Fuzzy match: Cremonese -> Cremonese (Score: 100)
# Fuzzy match: Marseille -> Marseille (Score: 100)
# Fuzzy match: Monza -> Monza (Score: 100)
# Fuzzy match: Genoa -> Genoa (Score: 100)
# Fuzzy match: Nott'm Forest -> Nott'ham Forest (Score: 93)
# Fuzzy match: Huesca -> Huesca (Score: 100)
# Fuzzy match: Nantes -> Nantes (Score: 100)
# Fuzzy match: Bologna -> Bologna (Score: 100)
# Fuzzy match: Holstein Kiel -> Holstein Kiel (Score: 100)
# Fuzzy match: Lorient -> Lorient (Score: 100)
# Fuzzy match: Nice -> Nice (Score: 100)
# Fuzzy match: Man United -> Leeds United (Score: 64)
# Fuzzy match: Roma -> Roma (Score: 100)
# Fuzzy match: Paderborn -> Paderborn 07 (Score: 86)
# Fuzzy match: Salernitana -> Salernitana (Score: 100)
# Fuzzy match: Wolfsburg -> Wolfsburg (Score: 100)
# Fuzzy match: Augsburg -> Augsburg (Score: 100)
# Fuzzy match: Toulouse -> Toulouse (Score: 100)
# Fuzzy match: Hoffenheim -> Hoffenheim (Score: 100)
# Fuzzy match: Getafe -> Getafe (Score: 100)
# Fuzzy match: Sevilla -> Sevilla (Score: 100)
# Fuzzy match: Brest -> Brest (Score: 100)
# Fuzzy match: Le Havre -> Le Havre (Score: 100)
# Fuzzy match: Sampdoria -> Sampdoria (Score: 100)
# Fuzzy match: Fiorentina -> Fiorentina (Score: 100)
# Fuzzy match: Monaco -> Monaco (Score: 100)
# Fuzzy match: Burnley -> Burnley (Score: 100)
# Fuzzy match: West Ham -> West Ham (Score: 100)
# Fuzzy match: Dijon -> Dijon (Score: 100)
# Fuzzy match: Lyon -> Lyon (Score: 100)
# Fuzzy match: Guingamp -> Guingamp (Score: 100)
# Fuzzy match: Las Palmas -> Las Palmas (Score: 100)
# Fuzzy match: Liverpool -> Liverpool (Score: 100)
# Fuzzy match: Levante -> Levante (Score: 100)
# Fuzzy match: Newcastle -> Newcastle Utd (Score: 82)
# Fuzzy match: Cardiff -> Cardiff City (Score: 74)
# Fuzzy match: Werder Bremen -> Werder Bremen (Score: 100)
# Fuzzy match: Darmstadt -> Darmstadt 98 (Score: 86)
# Fuzzy match: Leverkusen -> Leverkusen (Score: 100)
# Fuzzy match: Amiens -> Amiens (Score: 100)
# Fuzzy match: Mallorca -> Mallorca (Score: 100)
# Fuzzy match: Osasuna -> Osasuna (Score: 100)
# Fuzzy match: Angers -> Angers (Score: 100)
# Fuzzy match: Freiburg -> Freiburg (Score: 100)
# Fuzzy match: Verona -> Everton (Score: 77)
# Fuzzy match: Crystal Palace -> Crystal Palace (Score: 100)
# Fuzzy match: Valencia -> Valencia (Score: 100)
# Fuzzy match: Almeria -> Almería (Score: 86)
# Fuzzy match: Spezia -> Spezia (Score: 100)
# Fuzzy match: Union Berlin -> Union Berlin (Score: 100)
# Fuzzy match: Schalke 04 -> Schalke 04 (Score: 100)
# Fuzzy match: Fulham -> Fulham (Score: 100)
# Fuzzy match: Everton -> Everton (Score: 100)
# Fuzzy match: Betis -> Betis (Score: 100)
# Fuzzy match: Ath Madrid -> Real Madrid (Score: 76)
# Fuzzy match: Ath Bilbao -> Aston Villa (Score: 57)
# Fuzzy match: Sheffield United -> Sheffield Utd (Score: 90)
# Fuzzy match: Caen -> Caen (Score: 100)
# Fuzzy match: Juventus -> Juventus (Score: 100)
# Fuzzy match: Hamburg -> Hamburger SV (Score: 74)
# Fuzzy match: Elche -> Elche (Score: 100)
# Fuzzy match: Auxerre -> Auxerre (Score: 100)
# Fuzzy match: Lecce -> Lecce (Score: 100)
# Fuzzy match: Udinese -> Udinese (Score: 100)
# Fuzzy match: Cagliari -> Cagliari (Score: 100)
# Fuzzy match: Bielefeld -> Huddersfield (Score: 48)
# Fuzzy match: Chelsea -> Chelsea (Score: 100)
# Fuzzy match: Metz -> Metz (Score: 100)
# Fuzzy match: Barcelona -> Barcelona (Score: 100)
# Fuzzy match: RB Leipzig -> RB Leipzig (Score: 100)
# Fuzzy match: Alaves -> Alavés (Score: 83)
# Fuzzy match: St Etienne -> Saint-Étienne (Score: 78)
# Fuzzy match: Real Madrid -> Real Madrid (Score: 100)
# Fuzzy match: Wolves -> Wolves (Score: 100)
# Fuzzy match: Hertha -> Hertha BSC (Score: 75)
# Fuzzy match: Bayern Munich -> Bayern Munich (Score: 100)
# Fuzzy match: Montpellier -> Montpellier (Score: 100)
# Fuzzy match: Ajaccio -> Ajaccio (Score: 100)
# Fuzzy match: Sassuolo -> Sassuolo (Score: 100)
# Fuzzy match: Watford -> Watford (Score: 100)
# Fuzzy match: Celta -> Chelsea (Score: 67)
# Fuzzy match: Valladolid -> Valladolid (Score: 100)
# Fuzzy match: Nurnberg -> Nürnberg (Score: 88)
# Fuzzy match: Strasbourg -> Strasbourg (Score: 100)
# Fuzzy match: Girona -> Girona (Score: 100)
# Fuzzy match: Torino -> Torino (Score: 100)
# Fuzzy match: Frosinone -> Frosinone (Score: 100)
# Fuzzy match: Luton -> Luton Town (Score: 67)
# Fuzzy match: Huddersfield -> Huddersfield (Score: 100)
# Fuzzy match: Empoli -> Empoli (Score: 100)
# Fuzzy match: Parma -> Parma (Score: 100)
# Fuzzy match: Como -> Como (Score: 100)
# Fuzzy match: Chievo -> Chievo (Score: 100)
#
# Total mappings found: 149
#
# Sample of mappings (including exact matches):
# Cadiz -> Cádiz
# Fortuna Dusseldorf -> Düsseldorf
# Clermont -> Clermont Foot
# West Brom -> West Brom
# Brighton -> Brighton

# %%
team_name_mapping["Leeds"] = "Leeds United"
team_name_mapping["Bielefeld"] = "Arminia"
team_name_mapping["Man City"] = "Manchester City"
team_name_mapping["Man United"] = "Manchester Utd"

# %%
# Convert mapping dictionary to DataFrame
mapping_df = pd.DataFrame.from_dict(team_name_mapping, orient='index', columns=['mapped_name']).rename(columns={'mapped_name': 'odds_name'})
mapping_df.index.name = 'match_name'

# Save to CSV
mapping_df.to_csv('../../data/processed/team_name_mapping.csv')

print("Mapping saved to data/processed/team_name_mapping.csv")
print(f"Total mappings saved: {len(mapping_df)}")
# Out:
# Mapping saved to data/processed/team_name_mapping.csv
# Total mappings saved: 149

# %%
odds_data['HomeTeam'] = odds_data['HomeTeam'].apply(lambda x: team_name_mapping[x] if x in team_name_mapping else x)
odds_data['AwayTeam'] = odds_data['AwayTeam'].apply(lambda x: team_name_mapping[x] if x in team_name_mapping else x)

odds_data.to_csv('../../data/processed/odds.csv', index=False)
